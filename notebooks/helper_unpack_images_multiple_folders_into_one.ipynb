# %%
import os
import shutil
from pathlib import Path

# %%
Path.cwd()
# Out:
# PosixPath('/Users/mmadej/Desktop/Projects/gid-ml-framework/notebooks')

# %%
os.chdir('/Users/mmadej/Desktop/Projects/gid-ml-framework/data/01_raw/images_128_copy/')

# %%
Path.cwd()
# Out:
# PosixPath('/Users/mmadej/Desktop/Projects/gid-ml-framework/data/01_raw/images_128_copy')

# %%
path = Path.cwd()

# %%
destination = Path.cwd()

# %%
for child in path.iterdir():
    if not child.is_dir():
        continue
    for image in child.iterdir():
        if image.suffix=='.jpg':
            image.rename(destination/image.name)
    child.rmdir()

# %% [markdown]
# ### check, if any directories left

# %%
for child in path.iterdir():
    if child.is_dir():
        print(child)
